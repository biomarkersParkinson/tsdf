# %% [markdown]
# # Transform legacy format
#
# Transform one file (or all files within the given directory) from legacy TSDB to the current TSDF format (v0.1).

# %%
import os
from tsdf.legacy_tsdf_utils import (
    generate_tsdf_metadata_from_tsdb,
    convert_file_tsdb_to_tsdf,
    convert_files_tsdb_to_tsdf,
)

data_dir = 'data'

# %%
# Path to the metadata file
path_to_file = os.path.join(data_dir, "ppp_format_meta_legacy.json")
path_to_new_file = os.path.join(data_dir, "tmp_ppp_format_meta.json")

# Generate a TSDF metadata file from TSDB
generate_tsdf_metadata_from_tsdb(path_to_file, path_to_new_file)

# Convert a TSDB metadata file to TSDB format
# convert_metadata_tsdb_to_tsdf(path_to_file)

# Convert all metadata files in the directory from TSDB to TSDF format
# convert_metadatas_tsdb_to_tsdf(path_to_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 path_to_new_file = os.path.join(data_dir, "tmp_ppp_format_meta.json")
#       5 # Generate a TSDF metadata file from TSDB
# ----> 6 generate_tsdf_metadata_from_tsdb(path_to_file, path_to_new_file)
#       8 # Convert a TSDB metadata file to TSDB format
#       9 # convert_metadata_tsdb_to_tsdf(path_to_file)
#      10
#      11 # Convert all metadata files in the directory from TSDB to TSDF format
#      12 # convert_metadatas_tsdb_to_tsdf(path_to_dir)
#
# File ~\Documents\PhD\code\tsdf\src\tsdf\legacy_tsdf_utils.py:86, in generate_tsdf_metadata_from_tsdb(filepath_existing, filepath_new)
#      79 def generate_tsdf_metadata_from_tsdb(filepath_existing: str, filepath_new: str) -> None:
#      80     """
#      81     This function creates a metadata file (JSON) file in TSDF (0.1) format from a TSDB (legacy) file.
#      82
#      83     :param filepath_existing: The path to the JSON file to process
#      84     :param filepath_new: The path to the new JSON file
#      85     """
# ---> 86     with open(filepath_existing, "r") as f:
#      87         data = json.load(f)
#      88     new_data = convert_tsdb_to_tsdf(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\ppp_format_meta_legacy.json'
